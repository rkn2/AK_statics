# %% [markdown]
# # **Pre-Lesson content** 🍎

# %% [markdown]
# ## **Learning Objectives** 📗
#
# 1. Students will be able to understand the concept of equilibrium and define it as a state in which the sum of the forces acting on a structure are zero. Understanding of torque will come in a later lesson.
#
# 2. Students will be able to apply the concepts of vertical and horizontal equilibrium to calculate unknowns.
#
# 3. Students will comprehend how to visualize parametric relationships.

# %% [markdown]
# ## **Vocabulary** 🔤
#
# **Equilibrium**: The state in which the sum of forces and torques acting on a structure is zero, indicating that the structure is either stationary or moving at a constant velocity.
#
# **Support Forces:** The forces exerted on a structure, such as a highway bridge, at its support points (e.g., foundations, pillars). These forces are essential for maintaining equilibrium.
#
# **Vertical Equilibrium:** The condition in which the sum of vertical forces acting on a structure is zero, ensuring that the structure remains stationary in the vertical direction.
#
# **Horizontal Equilibrium:** The condition in which the sum of horizontal forces acting on a structure is zero, assuming there are no horizontal loads, ensuring the structure remains stationary in the horizontal direction.
#
# **Net Force:** The overall force acting on a structure, calculated as the vector sum of all individual forces acting in different directions.

# %% [markdown]
# ## **Sticking points** ⚠
#
# **Eccentricity**: Students may find it challenging to grasp the concept of eccentricity and its impact on bridge stability. Emphasize the idea that non-aligned forces can introduce torque and discuss how to calculate it.
#
# **Parametric Plot:** Creating and interpreting parametric plots can be challenging for some students. Guide them through the process and encourage them to describe the trends they observe.

# %% [markdown]
# # **Main Lesson 🎒: The First Condition for Equilibrium**

# %% [markdown]
# In the realm of mechanics, we examine a key scenario: equilibrium with zero net force and torque. This state signifies that an object, such as a person standing on a frozen pond, or a highway bridge over a lake, is either stationary or its center of mass moves at a constant velocity. Our focus primarily lies in the former, where the bridge or the person remains at rest.
#
# The study of statics enables us to calculate the forces to maintain equilibrium. Statics, a branch of physics, addresses the calculation of forces within objects to prevent significant deformation or fracture.
#
# Even when things appear stationary, like a person standing on a frozen lake, there are multiple forces at play. In this case, gravity pulls the person downward, while the ice below exerts an upward force on the person, counteracting gravity. Because the person remains still, according to Newton's second law, the net force acting on it is zero. This means that the upward force from the ice must be equal in strength to the downward force of gravity on the person. In such a state, the person is considered to be in equilibrium, meaning they are in a state of balance where the forces cancel each other out.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To ensure that the person remains in a state of "rest", we must apply Newton's second law, which dictates that the sum of all forces acting upon the person must equal zero. These forces are vector quantities, and to maintain equilibrium, it is imperative that the components of the net force are independently zero:
#
# $
# \sum F_x = 0
# $
# $
# \sum F_y = 0
# $
# $
# \sum F_z = 0
# $
#
# These equations, collectively known as the first condition for equilibrium, are fundamental in evaluating stability.

# %% [markdown]
# ## **Think Before You Calculate** 🤔
#
# ### **Question 1: Balancing Act**
# **Scenario:** You are standing perfectly still with your weight evenly distributed. You lift your left foot off the ground.
#
# **Question:** What happens to the force on your right foot?
#
# **Think about it:**
# - [ ] It stays the same
# - [ ] It doubles
# - [ ] It cuts in half
#
# <details>
# <summary>Click to see the answer</summary>
#
# **Answer:** It doubles!
#
# **Why?** To stay in equilibrium ($ΣF_y = 0$), the upward support force must equal your total weight. If one foot supports 0 lbs, the other must support 100% of your weight.
# </details>
#
# ---
#
# ### **Question 2: Center of Mass**
# **Scenario:** You are standing on two scales. You lean forward without moving your feet.
#
# **Question:** Do the scales still read the same number?
#
# **Think about it:**
# - [ ] Yes, my weight hasn't changed
# - [ ] No, the front scale reads higher
# - [ ] No, the back scale reads higher
#
# <details>
# <summary>Click to see the answer</summary>
#
# **Answer:** No, the front scale reads higher!
#
# **Why?** Shifting your center of mass changes how your weight is distributed between supports, even if the total weight stays the same.
# </details>

# %% [markdown]
# ## **Example**
# You've been tasked with evaluating the stability of a person standing on ice on a frozen lake. This assessment involves considering the forces acting on the person and the capacity of the ice to support their weight.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So what are our variables:
#
# Weight of the Person ($F_{W}$): This force acts vertically downward through the person's center of mass.
#
# Support Forces ($F_{N1}$ and $F_{N2}$): These forces represent the maximum upward support exerted by the ice underneath the person's left foot ($F_{N1}$) and right foot ($F_{N2}$) which are one foot apart from each other. We'll assume for now that the ice beneath the person's feet is uniform and equally supportive.
#
# Loading capacity of the Ice: For the purposes of this problem, let's use the value we calculated earlier and say that the ice has a loading capacity of approximately 200 lb.
#
#
# Your tasks:
# 1. Determine the support forces ($F_{N1}$ and $F_{N2}$) required to maintain the person in equilibrium, ensuring that the sum of forces in both the vertical and horizontal directions is equal to zero and that the weight is spread evenly in the feet. Express these forces in lb.
# 2. Assess whether the ice can effectively support the person by comparing the actual load on the ice to the loading capacity of the ice. Discuss whether the person is stable based on this comparison.

# %% [markdown]
# ### **Thinking in steps:** 🤔
# **Given:**
# - Ice Load Capacity = $P_{capacity}$ = $200 \text{lb}$
# - Weight = $F_{W}$ = 150 lb
#
# **Step 1**: Calculate Support Forces
#
# To calculate the support forces $FN1$ and $FN2$ for the person, we can use the equations of equilibrium.
#
# Equilibrium in the vertical direction:
# $$
# ΣF_y = 0 = F_{N1} + F_{N2} - F_{W} = 0
# $$

# %% [markdown]
# But why are $F_{N1}$ and $F_{N2}$ positive and $F_{W}$ is negative?
#
#
# The choice of signs in the equilibrium equations is a matter of convention and consistency. It's common practice to assign up as positive and down as negative.
#
# > ⬆ positive ⬇ negative
#
# Based on that convention, the weight of the person acts vertically downward. In the our chosen coordinate system (where upward is positive), the weight is considered negative because it acts in the opposite direction to the positive direction. The support forces from the ice act vertically upward to counteract the weight. In the chosen coordinate system, these support forces are considered positive because they act in the same direction as the positive direction.

# %% [markdown]
# ---
#
# ## **Interactive Coding Challenge** 💻
#
# ### **Task: Modify and Analyze**
#
# Now it's your turn! Modify the code below to explore different scenarios:
#
# **Challenge:** What happens if we add a 600 lb weight to the system?
#
# 1. Run the code below
# 2. Modify the `weights` list to include 600 lbs
# 3. Observe what happens to stability
# 4. **Discuss:** What does this tell us about safety limits?

# %%
# Interactive Challenge: Test Different Weights
# ===============================================

# TODO: Modify this list to include 600 lbs
weights = [100, 150, 200, 250]  # Add 600 to this list!

# Capacity per support
P_capacity = 120  # lbs

print("Testing different weights...\n")

for weight in weights:
    # Assume equal distribution
    FN1 = weight / 2
    FN2 = weight / 2
    total_weight = FN1 + FN2
    total_capacity = 2 * P_capacity
    
    # Check stability
    is_stable = total_weight <= total_capacity
    status = "✓ STABLE" if is_stable else "✗ UNSTABLE"
    
    print(f"Weight: {weight} lbs → {status}")
    print(f"  FN1 = {FN1:.1f} lbs, FN2 = {FN2:.1f} lbs")
    print(f"  Total: {total_weight:.1f} lbs / Capacity: {total_capacity} lbs")
    print()

print("\n💡 Discussion Questions:")
print("1. At what weight does the system become unstable?")
print("2. Why is it important to know the capacity limits?")
print("3. How would you design a system with a safety factor?")

# %% [markdown]
# The other equation of equilibrium we have is in the horizontal direction (here though we are assuming no horizontal load):
# $$
# ΣF_x = 0
# $$
#
# In terms of sign convention though, we would have a similar story to what happened above--the choice of signs is a matter of convention and consistency. Commonly people use the right as positive and the left as negative but it does not matter as long as you are consistent and clear in your assumptions when you are writing up your work!
#
#
#
#
# > ➡ positive
# >
# > ⬅ negative

# %% [markdown]
# So far we have 2 unknowns and 2 equations but one of them (the horizontal one) doesnt actually give us any information. Above in the problem though we said that the feet would evenly spread the load so our additional constraint here is that $F_{N1} = F_{N2}$.
#
# Now, let's solve these equations:
#
# Using vertical equilibrium, we find that:
# $$
# F_{N2}= \frac{F_W}{2}
# $$
#
#
# Substituting the given value for the weight of the person $F_W$:
#
# $$
# F_{N2} = \frac{150 lb}{2} = 75 \, \text{lb}
# $$
#
# Since $F_{N1} = F_{N2}$,
# $$
# F_{N1} = F_{N2}= 75 lb
# $$
#
# **Step 2,** Check if the person is stable:
#
# - If $P_{ice} \leq P_{capacity}$ , the person is stable.
# - If $P_{ice} > P_{capacity}$ , the person is not stable.
#
# **Results**
#
# After performing the calculations, we obtain the following results:
#
# * Support Force $F_{N1}$: 75 lb
# * Support Force $F_{N2}$: 75 lb
# * The person is stable!
#
# These results provide us with information about the support forces and the stability of the person based on the given data and calculations.
#
#
# Disclaimer: It's important to note that while these hand calculations provide a simplified analysis of the stability of a person standing on ice, real-world scenarios can be more complex. Factors such as variations in ice strength, temperature, and the distribution of a person's weight may impact the actual stability of the ice surface. Engineers and safety experts often employ safety factors and consider additional variables to ensure safety in practical situations. Therefore, these calculations serve as a starting point and should not be relied upon as the sole basis for assessing safety on ice.

# %% [markdown]
# ### **Coding time:**  💻

# %%
# Given data
P_capacity = 200  # Ice Bearing Capacity in lb
FW = 150  # Weight in lb

# Step 1: Calculate Support Forces
FN2 = FW / 2  # FN2 is half of the weight
FN1 = FN2  # FN1 is the same as FN2, maintaining symmetry

# Step 2: Check Stability
# Check if total weight is within total capacity (both feet)
total_weight = FN1 + FN2
total_capacity = 2 * P_capacity
if total_weight <= total_capacity:
    stability_result = "The person is stable."
else:
    stability_result = "The person is not stable."

# %% [markdown]
# So what is happening at this line? `if FN1 <= P_capacity:`?
#
# This line starts what is called an if statement. It checks if the value of $FN1$ (the calculated support force) is less than or equal to the ice bearing capacity ($P_{capacity}$). The condition $F_{N1} <= P_{capacity}$ is a comparison, and it evaluates to `True` if $F_{N1}$ is less than or equal to $P_{capacity}$, and `False` otherwise.
#
# If the condition is `True` (i.e., if $v$ is less than or equal to $P_{capacity}$), the code inside the indented block following the if statement is executed.
#
# ```
# stability_result = "The person is stable."
# ```
#
# This line assigns the string "The person is stable." to the variable `stability_result`.
#
# If the condition is `False` (i.e., if $F_{N1}$ is greater than $P_{capacity}$), the code inside the indented block following the else statement is executed
#
#
#
# ```
# stability_result = "The person is not stable."
#
# ```
# This line assigns the string "The person is not stable." to the variable `stability_result`.
#
# Now let's look at our results!

# %%
# Results
# Displaying the calculated support forces and stability result with commas
print("Support Force FN1: ", FN1, " lb,", "Support Force FN2: ", FN2, " lb,", stability_result)
# Out:
# Support Force S1:  75.0  lb, Support Force S2:  75.0  lb, The person is stable.

# %% [markdown]
# **Concept check:** Suppose you are tasked with evaluating the stability of a different person (or a person and a vehicle), and the weight is different from the one considered in the code. How would you use the provided Python code to determine the support forces ($F_{N1}$ and $F_{N2}$) and assess the person's stability for this new weight? Explain the steps and variables you would need to modify or input.

# %% [markdown]
# **Answer**: Change the value of the W variable to represent the weight of the new person or the person and a vehicle combination.
#
# Since the support forces are calculated based on the weight ($F_W$), the values of $F_{N1}$ and $F_{N2}$ will automatically adjust when you rerun the code with the new weight.
#
# The stability check is performed by comparing $F_{N1}$ with the ice bearing capacity ($P_{capacity}$). If $F_{N1}$ is less than or equal to $P_{capacity}$, the person is considered stable; otherwise, they are not stable.

# %% [markdown]
# Imagine you are tasked with analyzing the relationship between the weight of a person and the support force, $F_{N1}$, required to maintain equilibrium on ice. Below is a Python script that calculates support forces based on the ice bearing capacity and the different weights provided. For each new weight, $F_{N1}$ is updated and stored. Read through the code below to see how we can do this pythonically. Before you run it, try to map out by hand what the output will be. This will help you train your programming intuition!

# %%
import matplotlib.pyplot as plt

# Given data
P_capacity = 200  # Ice Bearing Capacity in lb

# List of different weights
weights = [150, 180, 200, 220, 450]  # Modify this list with different weights

# Initialize lists for support forces
support_forces = []

# Calculate support forces for each weight using loops
#This line starts a loop that iterates through each value in the list weights.
#The variable weight takes on each value in the list, one at a time, during each iteration of the loop.
for weight in weights:
    # Inside the loop, this line calculates the support force FN2 for the current weight.
    # It assigns half of the current weight to FN2.
    # This is based on the assumption that the support forces are symmetric, and FN2 is half of the weight.
    FN2 = weight / 2
    # This line assigns the value of FN2 to FN1. This step is taken to maintain symmetry, assuming equal support forces on both sides.
    FN1 = FN2

    # This line appends the value of FN1 to the list support_forces.
    # After each iteration of the loop, the calculated support force for the current weight is added to the list.
    support_forces.append(FN1)

    # This loop goes through each weight in the list, calculates the corresponding support forces FN1 and FN2,
    # ensures symmetry, and appends the calculated FN1 to the list support_forces.
    # The result is a list of support forces corresponding to each weight in the weights list.

# Plotting
plt.plot(weights, support_forces, marker='o', linestyle='-', color='b', label='Support Force (FN1)')
# plt.plot(): This is a function from the matplotlib.pyplot library used to create a line plot.
# weights, support_forces: These are the data points to be plotted. weights is on the x-axis, and support_forces is on the y-axis.
# Each pair (weights[i], support_forces[i]) represents a point on the plot.
# marker='o': This specifies the marker style for each data point. In this case, it uses a circular marker ('o').
# linestyle='-': This specifies the line style between the data points. Here, it uses a solid line ('-').
# color='b': This specifies the color of the line plot. 'b' represents blue.
# label='Support Force (FN1)': This provides a label for the line in the plot. It is useful when you want to add a legend to the plot later. The label is set to "Support Force (FN1)".
# The plt.plot() function is creating a line plot using the weights as x-coordinates, support_forces as y-coordinates, with circular markers, a solid blue line, and a label for the line in the legend.
# The resulting plot will show the relationship between weights and support forces, with each point marked and connected by a blue line.


plt.axhline(y=P_capacity, color='r', linestyle='--', label='Ice Bearing Capacity')  # Red line at FN1 = 200
# plt.axhline(): This is a function from the matplotlib.pyplot library used to add a horizontal line to the plot.
# y=P_capacity: This specifies the y-coordinate at which the horizontal line will be drawn. In this case, it's set to the value of P_capacity.
# color='r': This specifies the color of the horizontal line. 'r' represents red.
# linestyle='--': This specifies the line style for the horizontal line. Here, it uses a dashed line ('--').
# label='Ice Bearing Capacity': This provides a label for the horizontal line in the legend. It's set to "Ice Bearing Capacity".

plt.xlabel('Weight (lb)')  # Label for the x-axis
plt.ylabel('Support Force (FN1) (lb)')  # Label for the y-axis
plt.title('Relationship between Weight and Support Force')  # Title for the plot
plt.legend()  # Adding a legend to explain the plotted line

# Display the plot
plt.show()

# %% [markdown]
# ---
#
# ## **Example 2: Non-Symmetric Loading** 🎒
#
# ### **Real-World Scenario: Person Carrying a Heavy Backpack**
#
# The first example showed equal weight distribution. But what happens when the load is uneven?
#
# **Scenario:**
# - Person's weight: 150 lbs
# - Heavy backpack: 50 lbs
# - The backpack shifts the center of mass backward
# - This creates **unequal** forces on each foot
#
# **Key Concept:** When the center of mass shifts, one foot bears more weight than the other!
#
# ### **Setting Up the Problem:**
#
# Let's say the backpack shifts the center of mass so that:
# - Back foot (FN2) carries 60% of total weight
# - Front foot (FN1) carries 40% of total weight

# %%
# Non-Symmetric Example: Person with Backpack
# ============================================

# Given information
person_weight = 150  # lbs
backpack_weight = 50  # lbs
total_weight = person_weight + backpack_weight

# Weight distribution (due to shifted center of mass)
back_foot_percentage = 0.60  # 60% on back foot
front_foot_percentage = 0.40  # 40% on front foot

# Calculate forces on each foot
FN2 = total_weight * back_foot_percentage  # Back foot
FN1 = total_weight * front_foot_percentage  # Front foot

# Verify equilibrium (forces should sum to total weight)
print("="*50)
print("NON-SYMMETRIC LOADING ANALYSIS")
print("="*50)
print(f"Total Weight: {total_weight} lbs")
print(f"\nForce Distribution:")
print(f"  Front Foot (FN1): {FN1:.1f} lbs ({front_foot_percentage*100:.0f}%)")
print(f"  Back Foot (FN2): {FN2:.1f} lbs ({back_foot_percentage*100:.0f}%)")
print(f"\nVerification:")
print(f"  FN1 + FN2 = {FN1 + FN2:.1f} lbs")
print(f"  Total Weight = {total_weight} lbs")
print(f"  ✓ Equilibrium satisfied!" if abs((FN1 + FN2) - total_weight) < 0.1 else "  ✗ Error in calculation")

# Check stability
P_capacity = 120  # lbs per foot
total_capacity = 2 * P_capacity

print(f"\nStability Check:")
print(f"  Capacity per foot: {P_capacity} lbs")
print(f"  Total capacity: {total_capacity} lbs")
print(f"  Total weight: {total_weight} lbs")

if total_weight <= total_capacity:
    print(f"  ✓ STABLE - Total weight is within capacity")
else:
    print(f"  ✗ UNSTABLE - Exceeds capacity!")
print("="*50)

# %% [markdown]
# The plot illustrates the relationship between different weights (representing the load) and the corresponding support force ($F_{N1}$) required to maintain stability on ice.
#
# * The blue line represents the support force ($F_{N1}$) calculated for each weight in the list. As the weight increases, the support force also increases, following a linear relationship since $F_{N1}$ is calculated as half of the weight.
#
# * The red dashed line represents the ice bearing capacity ($P_{capacity}$), which is set at 200 lb. This line serves as a reference for the maximum support force that the ice can withstand before stability is compromised.
#
# * Points on the blue line above the red dashed line indicate situations where the support force ($F_{N1}$) exceeds the ice bearing capacity, suggesting potential instability.
#
# * Conversely, points below the red dashed line indicate stable conditions where the support force is within the ice bearing capacity.
#
# The plot visually demonstrates the relationship between weight and support force, allowing you to identify situations where the support force may exceed the ice bearing capacity, leading to potential instability.

# %% [markdown]
# ## **A note about solving for unknowns**
#
# In mathematics, when you have a system of two unknowns, you typically need two non-trivial equations to solve for those unknowns. This concept is rooted in the idea that each equation represents a relationship between the variables, and the solution is the point that satisfies both relationships simultaneously.
#
# Here, you have two equations, and each equation relates our knowns, $F_{N1}$ and $F_{N2}$, in a specific way. Since we didn't have any horizontal forces in the example above, the horizontal equilibrium equation was trivial. We used our knowledge of the problem, that the weight would have to be distributed equally if it was placed in the center to come up with our next equation, $F_{N1} = F_{N2}$. The solution to the system is the values of $F_{N1}$ and $F_{N2}$ that satisfy both equations. You can use various methods, such as substitution or elimination, to find the values of $F_{N1}$ and $F_{N2}$that make both equations true.
#
# The reason you need two equations is that one equation alone doesn't provide enough information to uniquely determine the values of both unknowns. Two equations create an overlap or intersection point in the solution space, narrowing down the possibilities to a specific solution.
#
# If you have more unknowns, you would generally need as many equations as the number of unknowns to uniquely determine the values of those unknowns. This is a fundamental concept in solving systems of linear equations, and it extends to more complex mathematical problems as well. But we are not always going to have the symmetry we had in this problem and we cannot always assume $F_{N1}$ and $F_{N2}$. So where do we get another equation? Stay tuned for more!

# %% [markdown]
# ---
#
# ## **Coding Practice: Three Levels** 🎓
#
# Choose the level that matches your comfort with coding:
#
# ### **📘 Level 1: Worked Example (Complete Code)**
# Study this complete solution for calculating support forces.

# %%
# 📘 LEVEL 1: Complete Worked Example
# ====================================

def calculate_support_forces(total_weight, position_percent=0.5):
    """
    Calculate forces on two feet/supports.
    position_percent: 0.5 means weight is centered (50/50).
    """
    force_1 = total_weight * (1 - position_percent)
    force_2 = total_weight * position_percent
    return force_1, force_2

# Example: 150 lb person, weight slightly shifted to right foot (60%)
f1, f2 = calculate_support_forces(150, 0.6)
print(f"Left Foot: {f1:.1f} lbs")
print(f"Right Foot: {f2:.1f} lbs")

# %% [markdown]
# ### **✏️ Level 2: Fill in the Blanks**
# Complete the missing parts.

# %%
# ✏️ LEVEL 2: Fill in the Blanks
# ===============================

def check_stability(total_weight, capacity_per_foot):
    # Calculate load per foot (assuming even distribution)
    load_per_foot = total_weight / 2
    
    # Check if load exceeds capacity
    if load_per_foot > capacity_per_foot:
        return "Unsafe!" # YOUR CODE HERE
    else:
        return "Safe" # YOUR CODE HERE

# Test
# print(check_stability(300, 140))

# %% [markdown]
# ### **🎯 Level 3: Build from Scratch**
# Write a function to solve the backpack problem.

# %%
# 🎯 LEVEL 3: Build from Scratch
# ===============================
# Task: Write a function that takes person_weight and backpack_weight
# and calculates the total force on the ground.

# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## **Exploration Tasks** 🔍
#
# ### **Task 1: The Heavy Backpack**
# **Question:** If a 150 lb person puts on a 50 lb backpack, how much does the total force on the ice increase?
#
# ### **Task 2: Shifting Weight**
# **Question:** If you lean forward so 70% of your weight is on your toes, calculate the specific force on your toes vs. heels.

# %% [markdown]
# ## **Key Takeaway** 💡
#
# Maintaining equilibrium, both in terms of forces and torques, is critical for the stability and safety of structures, especially highway bridges. Equilibrium ensures that the sum of forces and torques acting on the bridge is zero, and understanding this fundamental principle is essential for engineers and professionals responsible for building and maintaining infrastructure to ensure public safety.

# %% [markdown]
# ---
#
# ## **Clean Solution Reference** 📋
#
# Here's the complete workflow without extensive comments - use this as a reference!

# %%
# Clean Solution - Complete Workflow
# ===================================

# Given
total_weight = 200  # lbs
P_capacity = 120  # lbs per foot

# Calculate (assuming equal distribution)
FN1 = total_weight / 2
FN2 = total_weight / 2

# Check stability
total_capacity = 2 * P_capacity
is_stable = (FN1 + FN2) <= total_capacity

# Display
print(f"FN1 = {FN1} lbs")
print(f"FN2 = {FN2} lbs")
print(f"Status: {'STABLE' if is_stable else 'UNSTABLE'}")
