# %% [markdown]
# # **Translating Physics Problems into Code Outlines: A Guide for Teachers 🍎**

# %% [markdown]
# Welcome! This mini-lesson for teachers focuses on a critical intersection of physics and modern problem-solving: the art of translating physics word problems into programming languages / code. As we dive into this topic, our  aim is to empower you with the essential skills required to guide your high school students through the converting  physics scenarios into executable code.
#
# You are well aware that physics is a subject rooted in real-world scenarios, and translating these scenarios into code provides a tangible link between theoretical concepts and practical application. By the end of this lesson, you will possess the tools to facilitate this connection for your students, enabling them to approach physics challenges with a computational mindset.
#
# Our focus in this lesson will be on creating what we call "code outlines" or "code scaffolds." These structured representations will serve as a roadmap, guiding students through the logical steps required to solve physics problems computationally. Whether it's calculating forces, determining equilibrium conditions, or simulating physical phenomena, code outlines will lay the foundation for coding proficiency in the context of physics.

# %% [markdown]
# # **What is a code outline?**

# %% [markdown]
# A code outline is akin to a blueprint or a structured plan that serves as a guide for solving a specific problem. It is a high-level representation of the logical steps and key components required to achieve a desired outcome, all before diving into the nitty-gritty details of writing the actual code. This preliminary structure allows students learning to code, to organize their thoughts, identify patterns, and establish a clear roadmap for their solution.
#
# Now, let's break down the key components of a code outline:
#
# **Step 1: Problem Understanding:** Clearly articulate the problem at hand. What is the physics scenario you're trying to model or solve? Understand the problem thoroughly before attempting to convert it into code.
#
# **Step 3: Variable Assignments:** Identify the constants and save them as variables in your code. These are the entities whose values will be constant as the program runs and we will need to call on them. Assign initial values to these variables based on the problem's context.
#
# **Step 4: Calculations:** Outline the mathematical or logical calculations required to solve the problem. This could involve applying physics formulas, performing arithmetic operations, or implementing algorithms relevant to the scenario.
#
# **Step 5: Print Statements:** Define where and how the results should be displayed. This involves using print statements or equivalent output mechanisms to communicate the computed values or outcomes.

# %% [markdown]
# # **Walking through an example**

# %% [markdown]
# Problem: A ball is launched from the ground at an angle θ = 45 to the horizontal with an initial velocity $V_0$ of 5 ft / second. Ignoring air resistance, write a Python code to calculate the maximum height reached by the ball.
#
# **Problem Understanding**
#
# The first thing you want is for your students to clearly define the physics problem and identify what needs to be calculated: maximum height.
#
# So your code outline could say something like:

# %%
# Clearly define the physics problem and identify what needs to be calculated: maximum height.
# Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you are coding.

# %% [markdown]
# So to solve this problem we will be using the projectile motion equation:
#
# $$
# h_{max} = h_0 + 0.5 \times a \times t^2 + v_{0y}\times t
# $$
#
# where:
# * $h_0$ is the initial height which would be 0 in this case
#
# * $a$ is the constant of acceleration
#
# * $t$ is the time it takes to get to the apex position
#
# * $v_{0y}$ is the y component of the initial velocity
#
# To calculate the time we could use this equation since there is no y component of velocity at the apex:
#
# $$
# t = v_{0y}/a
# $$
#
# Encourage your students to write these things down as comments in their code before they reall get going. So this could look like:

# %%
# Clearly define the physics problem and identify what needs to be calculated: maximum height.
# Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you are coding.
# For projectile motion, we will be using the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t
  # Where:
  # - h_0 is the initial height (which is 0 in this case)
  # - a is the constant of acceleration (gravity, assumed constant)
  # - t is the time it takes to get to the apex position
  # - v_0y is the y component of the initial velocity
# To calculate the time (t), we can use the equation t = v_0y/a since there is no y component of velocity at the apex

# %% [markdown]
# **Variable Assignments**
# So looking at those two equations, we would need to define gravity as our first constant and the y component of our initial velocity as our second. So our code outline could say something like:

# %%
# Define your given data
# Set a equal to -32ft/s2
# Set v0y equal to the initial velocity times sin(theta)

# %% [markdown]
# **Calculations**
#
# Next we need to set up how our calculations are going to be done so we could say something like this in our outline:

# %%
# Define your formulas that you will need
# To calculate the time, write out the equation t = v_0y/a since there is no y component of velocity at the apex
# To calculate the max height, write out the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t

# %% [markdown]
# **Print Statements**

# %%
# Display results

# %% [markdown]
# So in total the code outline could look something like this:

# %%
# Clearly define the physics problem and identify what needs to be calculated: maximum height.
# Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you are coding.
# For projectile motion, we will be using the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t
  # Where:
  # - h_0 is the initial height (which is 0 in this case)
  # - a is the constant of acceleration (gravity, assumed constant)
  # - t is the time it takes to get to the apex position
  # - v_0y is the y component of the initial velocity
# To calculate the time (t), we can use the equation t = v_0y/a since there is no y component of velocity at the apex


# Define your given data
# Set a equal to -32ft/s2
# Set v0y equal to the initial velocity times sin(theta)

# Define your formulas that you will need
# To calculate the time, write out the equation t = v_0y/a since there is no y component of velocity at the apex
# To calculate the max height, write out the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t

# Display results

# %% [markdown]
# and your students code could look something like this interspersed

# %%
# - Clearly define the physics problem and identify what needs to be calculated: maximum height.
# - Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you are coding.
# - For projectile motion, we will be using the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t
#   Where:
#   - h_0 is the initial height (which is 0 in this case)
#   - a is the constant of acceleration (gravity, assumed constant)
#   - t is the time it takes to get to the apex position
#   - v_0y is the y component of the initial velocity
# - To calculate the time (t), we can use the equation t = v_0y/a since there is no y component of velocity at the apex

# - Define your given data
# - Set a equal to -32 ft/s^2
# - Set v0y equal to the initial velocity times sin(theta)
a = -32  # acceleration due to gravity in ft/s^2
v0 = 5  # initial velocity in ft/s
theta = 45  # launch angle in degrees

# Define your formulas that you will need
# To calculate the time, write out the equation t = v_0y/a since there is no y component of velocity at the apex
# To calculate the max height, write out the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t
v0y = v0 * sin(theta)
t = v0y / a
h_max = 0.5 * a * t**2 + v0y * t

# Display results
print("Maximum Height:", h_max, "ft")

# %% [markdown]
# When they go to run this though, they will get an error: ![image.png](data:image/png;base64,...)

# %% [markdown]
# to use sin they need to import the relevant package. So the updated code outline and code would be:

# %%
# - Clearly define the physics problem and identify what needs to be calculated: maximum height.
# - Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you are coding.
# - For projectile motion, we will be using the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t
#   Where:
#   - h_0 is the initial height (which is 0 in this case)
#   - a is the constant of acceleration (gravity, assumed constant)
#   - t is the time it takes to get to the apex position
#   - v_0y is the y component of the initial velocity
# - To calculate the time (t), we can use the equation t = v_0y/a since there is no y component of velocity at the apex

# Am I going to need any external packages?
# Yes sin!
from math import sin

# - Define your given data
# - Set a equal to -32 ft/s^2
# - Set v0y equal to the initial velocity times sin(theta)
a = -32  # acceleration due to gravity in ft/s^2
v0 = 5  # initial velocity in ft/s
theta = 45  # launch angle in degrees

# Define your formulas that you will need
# To calculate the time, write out the equation t = v_0y/a since there is no y component of velocity at the apex
# To calculate the max height, write out the equation: h_max = h_0 + 0.5 * a * t^2 + v_0y * t
v0y = v0 * sin(theta)
t = v0y / a
h_max = 0.5 * a * t**2 + v0y * t

# Display results
print("Maximum Height:", h_max, "ft")
# Out:
# Maximum Height: -0.8484806344506857 ft

# %% [markdown]
# # **Another example**
#
# Calculate the horizontal range of a projectile launched at an angle.
#
# Here is your code outline:

# %%
# Clearly define the physics problem and identify what needs to be calculated: horizontal range.
# Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you ar
# For projectile motion, we will be using the equation: R = v_0x * t
  # Where:
  # - R is the horizontal range
  # - v_0x is the x component of the initial velocity
  # - t is the total time of flight

# Define your given data
# Set a equal to -32 ft/s^2 (acceleration due to gravity)
# Set v_0 equal to the initial velocity (magnitude)
# Set theta equal to the launch angle in degrees

# Define your formulas that you will need
# To calculate the horizontal range, write out the equation: R = v_0x * t
# To calculate the total time of flight, write out the equation: t = 2 * v_0y / a

# %% [markdown]
# and here is your code inside your outline

# %%
# - Clearly define the physics problem and identify what needs to be calculated: horizontal range.
# - Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you a
# - For projectile motion, we will be using the equation: R = v_0x * t
#   Where:
#   - R is the horizontal range
#   - v_0x is the x component of the initial velocity
#   - t is the total time of flight
# - To calculate the horizontal range, write out the equation: R = v_0x * t
# - To calculate the total time of flight, write out the equation: t = 2 * v_0y / a

# - Define your given data
# - Set a equal to -32 ft/s^2
# - Set v_0 equal to the initial velocity
# - Set theta equal to the launch angle in degrees
a = -32  # acceleration due to gravity in ft/s^2
v0 = 10  # initial velocity in ft/s
theta = 30  # launch angle in degrees

# - Define your formulas that you will need
# - To calculate the horizontal range, write out the equation: R = v_0x * t
# - To calculate the total time of flight, write out the equation: t = 2 * v_0y / a
v0x = v0 * cos(theta)
v0y = v0 * sin(theta)
t = 2 * v0y / -a  # negative sign because acceleration is in the opposite direction of motion
R = v0x * t

# - Display results
print("Horizontal Range:", R, "ft")

# %% [markdown]
# # **Plotting example**
#
# Plot the trajectory of your object using matplotlib with the parametric equations for projectile motion.
#
# Here is your code outline:

# %%
# Clearly define the physics problem and identify what needs to be calculated: trajectory.
# Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you ar
# For projectile motion, we will be using the parametric equations:
  # x(t) = v_0x * t
  # y(t) = h_0 + v_0y * t + 0.5 * a * t^2
    # Where:
    # - v_0x is the x component of the initial velocity
    # - v_0y is the y component of the initial velocity
    # - h_0 is the initial height
    # - a is the constant acceleration (gravity, assumed constant)

# Define your given data
# Set a equal to -32 ft/s^2 (acceleration due to gravity)
# Set v_0 equal to the initial velocity
# Set theta equal to the launch angle in degrees
# Set h_0 equal to the initial height (let's assume it's 0 for simplicity)

# Define your formulas that you will need
# To calculate the x and y positions, use the parametric equations for projectile motion

# Plot the trajectory using matplotlib

# %% [markdown]
# and here is your code inside your outline

# %%
# - Clearly define the physics problem and identify what needs to be calculated: trajectory.
# - Think about what the governing equations are for your problem at hand and write them down so you can refer to them when you a
# - For projectile motion, we will be using the parametric equations:
#   x(t) = v_0x * t
#   y(t) = h_0 + v_0y * t + 0.5 * a * t^2
#     Where:
#     - v_0x is the x component of the initial velocity
#     - v_0y is the y component of the initial velocity
#     - h_0 is the initial height
#     - a is the constant acceleration (gravity, assumed constant)

# - Define your given data
# - Set a equal to -32 ft/s^2
# - Set v_0 equal to the initial velocity
# - Set theta equal to the launch angle in degrees
# - Set h_0 equal to the initial height
a = -32  # acceleration due to gravity in ft/s^2
v0 = 10  # initial velocity in ft/s
theta = 45  # launch angle in degrees
h0 = 0  # initial height

from math import sin
from math import cos

# - Define your formulas that you will need
# - To calculate the x and y positions, use the parametric equations for projectile motion
v0x = v0 * cos(theta)
v0y = v0 * sin(theta)

# - Plot the trajectory using matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Time points
t_points = np.linspace(0, 2 * v0y / -a, num=100)
# x and y positions
x_points = v0x * t_points
y_points = h0 + v0y * t_points + 0.5 * a * t_points**2

# Plotting
plt.plot(x_points, y_points)
plt.title('Projectile Motion Trajectory')
plt.xlabel('Horizontal Distance (ft)')
plt.ylabel('Vertical Distance (ft)')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Sticking points:**
#
# Creating a code outline can be a crucial step in helping students understand the logic and structure of a program! However, there are some. common sticking points you could run into when making a code outline. Here are some of those points and how to mitigate them:
#
#
# **Unclear Variable Definitions:**
#   * Sticking Point: Students may struggle with understanding the difference in variables or constants used in the problem versus their code.
#   * Mitigation: Encourage students to use clear and explicit comments in their code. For instance, when a constant like gravity `g` is declared in the code, students should add comments clarifying that, although it's stored as a variable, its value remains constant throughout the problem.
#
#
#
# ```
# # Constants
# g = 9.8  # Acceleration due to gravity in ft/s^2 (remains constant)
# ```
#
#
#
# **Complexity Overload:**
#   * Sticking Point: Teachers may unintentionally make the code outline too complex, leading to confusion.
#   * Mitigation: Break down the problem into smaller, manageable steps. Clearly define the tasks and guide students through one step at a time. You can even break code into multiple code blocks if that makes it easier for the students to read.
