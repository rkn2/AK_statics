# %% [markdown]
# # **Pre-Lesson content** 🍎

# %% [markdown]
# ## **Learning Objectives** 📗
#
#
# 1. Students will be able to understand the concept of equilibrium in both translational and rotational contexts as well as recognize the conditions required for an object to be in equilibrium.
#
# 2. Students will be able to calculate torque in real-world scenarios and understand the significance of a lever arm distance.

# %% [markdown]
# ## **Sticking points** ⚠
#
# **Sign Convention for Torque:** The introduction of a negative sign in the torque equation and its association with clockwise and counterclockwise rotations might be confusing. Ensuring that students understand the chosen sign convention and its consistent application is crucial.
#
# **Torque vs moment:** "Torque" and "moment" are terms often used interchangeably. When we talk about our condition for equilibrium we use torque since it is the more generic term about the tendency of a force to rotate an object about an axis, We will use moment when we are referring to a specific external moment connection or a value we are calculating at a specific point.
#
# **Moment Connections and Additional Torques:** The idea of moment connections and the inclusion of additional torques beyond the direct weight force might be a potentially complex concept. Students may struggle to understand why certain torques exist and why they are essential for rotational equilibrium.

# %% [markdown]
# ## **Vocabulary** 🔤
#
# **Torque** is a measure of the rotational force or tendency to rotate applied to an object. It is calculated as the product of the lever arm distance and the force applied perpendicular to the lever arm.
#
# **Moment connection:** A moment connection refers to a joint or connection in a structure that allows for the transmission of both forces and torques between connected components. It is significant in providing stability and preventing rotation in structural systems.
#
# **Lever arm:** The lever arm, also known as the moment arm, is the perpendicular distance from the pivot point to the line of action of a force. It is a crucial parameter in torque calculations.
#
# **Stable equilibrium:** Stable equilibrium occurs when an object, when disturbed, returns to its original position. For stable equilibrium, the object's center of gravity should be directly above its point of support.
#
# **Unstable equilibrium**: Unstable equilibrium occurs when a slight disturbance leads to continuous motion, and the object does not return to its original position. This often happens when the center of gravity shifts away from the point of support.
#
# **Material fatigue**: Material fatigue is the weakening of a material over time due to repeated loading and unloading. It can lead to structural failure and is a consideration in setting safe operating limits.

# %% [markdown]
# # **Main Lesson 🎒: The Second Condition For Equilbrium**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# While those equations we looked at last lesson are necessary for an object to be in equilibrium, they do not always suffice. In the figure above, you have a pickup truck equipped with a folding truck-mounted crane with an electric winch and you need to lifting fish from the ground. Despite the fact that the forces $F_W$ and $F_N$ would be in equilibrium, they generate a net torque capable of rotation. Thus for that crane to not rotate, there has to be another equation at play!
#
# $$
# \sum\tau=0
# $$
# Therefore we can establish the second condition for equilibrium: the sum of torques acting on an object, calculated about any axis, must equate to zero.
#
# But what is this torque, $\tau$?
#
# $$
# \tau= d_{arm} \times F_{applied}
# $$
#
# $d_{arm}$ is the lever arm or the perpendicular distance from the pivot point to the line of action of the force.
#
# $F_{applied}$ is the applied force or in this case the load of fish.
#
# Let's try calculating what the torque at point A, the pivot point, would be in an example.

# %% [markdown]
# ## **Example 1**

# %% [markdown]
# In the figure above, you have a pickup truck equipped with a folding truck-mounted crane with an electric winch and you need to lift 1000lb of fish from the ground. The crane is attached to the bed of the truck and the electronic winch is used to lift the load vertically. The length of the crane arm from the pivot point to the hook is 46 inches. Calculate how much torque exists at the pivot point when the fish are hoisted up.

# %% [markdown]
# ### **Thinking in steps:** 🤔

# %% [markdown]
# **Given:**
# - Weight = $F_W$ = 1000 lb
# - Arm distance = $d_{arm}$ = 46" (about 3.8 ft)
#
# **Step 1:** Write out your equations of equilibrium for forces like we did in the previous lesson
#
# Equilibrium in the vertical direction:
# $$
# ΣF_y = 0 = F_N - F_W = 0
# $$
#
# Equilibrium in the horizontal direction is trivial (assuming no horizontal load):
# $$
# ΣF_x = 0
# $$
#
# **Step 2:** Now we also have another equation to consider: torque!
#
# $$
# \sum\tau_{A}=0 = d_{arm} \times F_{W} + d_{arm} \times F_{N}
# $$
#
# Now we are interested in understanding how much torque occurs at point A. So how far away is point A from where our normal force is applied?
#
# They are coincident! That means that $d_{arm}$ for our $F_{N}$ is 0 and so that term goes to 0 for our equation above. That means we are just left with:
#
# $$
# \sum\tau_{A}=0 = d_{arm} \times F_{W}
# $$
#
# So now we have three equations that we can use to understand how much torque exists at the pivot point when the fish are hoisted up.
#
# $$
# \sum\tau_{A}=0 = 3.8\text{ft} \times 1000 \text{lb}
# $$
#
# But that doesn't make sense!? How does 0 = 380 lbft?
#
# Well it turns out that there is another term in that figure that we did not account for in our torque equation, the actual torque we are trying to solve for! So instead our equation should look like
#
# $$
# \sum\tau_{A}=0 = 3.8\text{ft} \times 1000 \text{lb} - \tau_A
# $$
#
# **Results:**
#
# After substituting our real values back into that equation we get
#
# $$
# \tau_{A} = 380 \text{lbft in the clockwise direction}
# $$
#
# But now you might have more questions like...
#
# 1.  Where did that term come from?
# 2.  Why do we have it on one end of the crane but not the other?
# 3.  How did we know what direction to draw it in our freebody diagram?
# 4.  And why is there a negative sign in front of $\tau_A$? And what does "in the clockwise direction" mean?

# %% [markdown]
# ### **Clarifying confusing points:**❓❓❓
#
#
# So let's start with one of those questions at a time:

# %% [markdown]
# **1. Where did that term come from?**
#
# In the context of a crane lifting a load, the torque $\tau_A$ at point A represents the contribution to the rotational equilibrium of the system due to factors other than the weight of the fish. The equation $\sum\tau = 0$ is a statement that the sum of all torques acting on the system must be zero for the system to be in rotational equilibrium.
#
# Now, consider the corrected equation:
#
# $$
# \sum\tau_{A} = 0 = d_{\text{arm}} \times F_{W} - \tau_A
# $$
#
# The first term $d_{\text{arm}} \times F_{W}$ accounts for the torque generated by the weight of the fish acting at a distance $d_{\text{arm}}$ from the pivot point. However, there might be other torques $\tau_A$ acting at point A like the components within the crane, such as motors and the fastening of the crane to the truck bed (can be referred to as a moment connection), which create torques that affect the equilibrium.
#
# When we refer to the "fastening of the crane to the truck bed" as a "moment connection," we are describing a type of joint or connection that allows for the transmission of both forces and torques between the crane and the truck bed. A moment connection allows the transmission of torques or moments between the crane and the truck bed. This torque transmission is significant when considering the rotational equilibrium of the system.
#
# In essence, $\tau_A$ is a placeholder for additional torques that may exist due to various factors in the system. It's the *sum* of all torques at the pivot point A that prevent the crane from tipping over. If we didn't fasten the crane to the truck and instead just placed it in the bed, our system would not be able to generate $\tau_A$ and it would fall over! Including $\tau_A$ in the equation ensures that the rotational equilibrium condition is comprehensive, accounting for all relevant torques in the system.

# %% [markdown]
# **2. Why do we have $\tau_A$ on one end of the crane but not the other?**
#
# $\tau_A$ exists because of the moment connection that we just talked about. It doesnt exist on both sides of the crane, it just exists where the bolts are fastened to the truck bed. Since there isn't a similar mechanism on the other end of our crane (where our fish are hooked on) that side doesn't have the capacity to counter act rotation.

# %% [markdown]
# **3. How did we know what direction to draw it?**
#
# Okay well let's think about the situation above before we knew $\tau_A$ existed. If we didn't fasten the crane to the truck bed and we tried to hoist our fish up, the crane would tip clockwise about the pivot point.
#
# But since we did fasten our crane to the truck bed, when we go to hoist our fish up, the moment connection is trying to prevent the crane from rotating clockwise and so it is acting counterclockwise.

# %% [markdown]
# **4. Why is there a negative sign in front of $\tau_A$?**
#
# Again, it is important to remember that the choice of signs in the equilibrium equations is a matter of convention and consistency. When looking at rotations it's common practice to assign clockwise as positive and counterclockwise as negative. Based on that convention, the weight of the fish would spin the crane clockwise around point A and it is positive; $\tau_A$ though is acting in the opposite direction and so we write that with a negative sign.
#
# So looking back at question 3, what would happen if we had drawn $\tau_A$ going the othe way and we had assumed that $\tau_a$ was trying to rotate the crane clockwise about point A? In that case we would have just ended up with a negative value which would have indicated that we chose our direction wrong.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# It would have looked like:
#
# $$
# \sum\tau=0 = 3.8\text{ft} \times 1000 \text{lb} + \tau_A
# $$
#
# $$
# \tau_A = - 380 \text{lbft}
# $$
#
# That negative sign there would have indicated that we had made a wrong assumption about the direction  $\tau_a$  was trying to rtate our crane.
# And so we would say that:
# $$
# \tau_A = -380 \text{lbft in the counterclockwise direction}
# $$
# or
# $$
# \tau_A = 380 \text{lbft in the clockwise direction}
# $$

# %% [markdown]
# ### **Coding time:**  💻

# %% [markdown]
# So now lets try to do this pythonically!
#
# Write out the equations of equilibrium for the given system, considering vertical and horizontal directions.
#
# Include the equation for torque ($\sum\tau)$ and explain the significance of $d_{arm}$ in this context.
#
# Calculate the torque at point A when the fish are hoisted up, considering the provided arm distance.

# %%
# Given data
FW = 1000  # lb
Arm_distance = 46 / 12  # Convert inches to feet

# Equations of equilibrium
# Equilibrium in the vertical direction
FN = FW

# Equilibrium in the horizontal direction
# Nothing because no horizontal load

# Third equation for torque
tau_A = FW * Arm_distance

# Print the result
print("The torque at point A is ", tau_A, "lbft in the clockwise direction.")
# Out:
# The torque at point A is  3833.3333333333335 lbft in the clockwise direction.

# %% [markdown]
# ### **So what does this mean?:** 🤔

# %% [markdown]
# So let's assume that this is the maximum allowable torque at point A for the given moment connection. The crane in this example can extend to 57". What should the maximum weight limit be when at maximum extension so that the allowable torque is not exceeded?

# %%
# Teachers choice!
# This code cell can be deleted so the students have to write it on their own from scratch
# OR This code cell can be modified to be pseudo code or a code outline so students have to complete the code on their own

      # Here is an example of what you could give for a code outline
      # Define your given data
      # Set maximum_extension to 57 divided by 12
      # Set allowable_torque to tau_A
      # Calculate the maximum allowable weight
      # Set maximum_allowable_weight to allowable_torque divided by maximum_extension
      # Print the result

# OR This code cell can be left as is so students have an example to work from and they can be encouraged to just change values

# Given data
maximum_extension = 57 / 12  # Convert inches to feet
# Calculate torque using τ = F × d (Equation 3.1)
allowable_torque = tau_A  # lbft

# Calculate the maximum allowable weight
# Calculate torque using τ = F × d (Equation 3.1)
maximum_allowable_weight = allowable_torque / maximum_extension

# Print the result
print("Maximum allowable weight at maximum extension:", maximum_allowable_weight, "lb")
# Out:
# Maximum allowable weight at maximum extension: 807.0175438596492 lb

# %% [markdown]
# **Resources for the teacher 🍎:** To learn more about how to write code outlines, see [How To Write A Code Outline](https://colab.research.google.com/drive/17slmbjVnhYL35y4O4PI1sh7GQCI549vz?usp=sharing)

# %% [markdown]
# If you read the manual for this crane though, they say that you should not put a load greater than 220lb on it when you extend it that far. Calculate what the torque would be at point A for that load.

# %%
# Teachers choice!
# This code cell can be deleted so the students have to write it on their own from scratch
# OR This code cell can be modified to be pseudo code or a code outline so students have to complete the code on their own
      # Here is an example of what you could give for a code outline
      # Define your given data
      # Set maximum_extension to 57 divided by 12
      # Set maximum_allowable_load to 220

      # Calculate the torque at point A when extended to the maximum length
      # Set tau_max_extension to maximum_allowable_load multiplied by maximum_extension

      # # Print the results
# OR This code cell can be left as is so students have an example to work from and they can be encouraged to just change values

# Given data
maximum_extension = 57 / 12  # Convert inches to feet
maximum_allowable_load = 220  # lb

# Calculate the torque at point A when extended to the maximum length
tau_max_extension = maximum_allowable_load * maximum_extension

# Print the results
print("Torque at point A under recommended max loading at max extension:", tau_max_extension, "lbft")
# Out:
# Torque at point A under recommended max loading at max extension: 1045.0 lbft

# %% [markdown]
# Since the calculated torque is less than the maximum allowable torque, it verifies that putting a 220 lb load when the crane is extended to 57 inches would be within the safe operating limits of the crane's moment connection.
#
# Why does it make sense though that the torque would be so much smaller at the maximum extension?
#
# The recommended maximum load or torque limits provided by manufacturers are typically based on a combination of factors.
# * Manufacturers often incorporate safety margins into their specifications to ensure the safe operation of the equipment. The recommended limits are set lower than the theoretical maximum capacity to provide a buffer for uncertainties, variations in materials, potential wear and tear, and other unforeseen factors.
# * Materials, especially metals, can experience fatigue and wear over time with repeated loading and unloading. Manufacturers consider the material properties and design the equipment to withstand a certain number of loading cycles without failure. Setting conservative load limits helps extend the life of the equipment and reduces the risk of material fatigue.
#
# While it might seem that the equipment could handle a higher load based on theoretical calculations, the recommended limits are established to prioritize safety and reliability. Users should always adhere to the manufacturer's specifications and guidelines to ensure the safe and proper use of equipment.

# %% [markdown]
# ## **Example 2**
# So let's go back and look at our problem from the previous lesson. Before, to solve this without the second condition for equilibrium we needed to assume that $F_{N1} = F_{N2}$. What if we didn't assume that though?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 1:** So let's assume that $F_W$ is acting at the center of the body and that the feet are placed a foot apart from each other.  In terms of equations for force we have:
#
# Equilibrium in the vertical direction:
# $$
# ΣFy = 0 = F_{N1} + F_{N2} - F_W = 0
# $$
#
# $$
# ΣFy = 0 = F_{N1} + F_{N2} - 150\text{lb} = 0
# $$
#
# Equilibrium in the horizontal direction (assuming no horizontal load):
# $$
# ΣFx = 0
# $$
#
# **Step 2:** Consider torque! Now we also have a third equation
#
# $$
# \sum(\tau_{pt1})=0 = d_{arm} \times F_{N1} - d_{arm} \times F_{N2} + d_{arm} \times F_{W}
# $$
#
# Remember that the term associated with the weight will be trying to turn the person clockwise about point 1 and so we consider that to be positive. Additionally $d_{arm}$ for $F_{N1}$ is 0 since there is no distance between point 1 and where that force is applied.
#
# $$
# \sum(\tau_{pt1})=0 = - 1\text{ft} \times F_{N2} + 0.5 \text{ft} \times 150 \text{lb}
# $$
#
# **Results**
# So we can take this equation and our equation for vertical equilibrium above and solve them for both unknowns to get the same answer that we did when we made our assumptions in the last lesson.

# %% [markdown]
# ## **A note about stability and balance**
#
# An object in static equilibrium, when undisturbed, experiences no translational or rotational acceleration because the total sum of forces and torques acting on it is zero. Generally, an object with its center of gravity (cg) situated directly above its point of support, such as a net full of fish, tends to be in stable equilibrium. Stable equilibrium means that if the net is gently nudged to one side and then released, it will return to its original position.

# %% [markdown]
# ---
#
# ## **Step-by-Step Code Outline** 📝
#
# When solving torque problems, follow this systematic approach:
#
# ### **Step 1: Define Known Quantities**
# ```python
# # Example: Crane with fish
# fish_weight = 50  # lbs (Force)
# crane_length = 10  # ft (Distance)
# ```
#
# ### **Step 2: Identify the Pivot Point**
# ```python
# # Usually at the support or where rotation occurs
# pivot_point = 'support'  # or 'center', 'end', etc.
# ```
#
# ### **Step 3: Calculate Lever Arm**
# ```python
# # Perpendicular distance from force to pivot
# lever_arm = crane_length  # ft
# ```
#
# ### **Step 4: Calculate Torque** (Equation 3.1: τ = F × d)
# ```python
# torque = fish_weight * lever_arm  # lb·ft
# print(f"Torque: {torque} lb·ft")
# ```
#
# ### **Step 5: Check Equilibrium**
# ```python
# # Sum of torques should equal zero (or reaction torque)
# # ΣM = M_reaction + M_applied = 0
# ```
#
# ### **Step 6: Verify Results**
# ```python
# # Check units, magnitudes, and physical meaning
# ```

# %% [markdown]
# ---
#
# ## **Factor of Safety (FoS) in Engineering** ⚖️
#
# ### **What is Factor of Safety?**
#
# The **Factor of Safety (FoS)** is the ratio of a structure's ultimate (maximum) capacity to its working (actual) load.
#
# **Formula:**
#
# $$\text{FoS} = \frac{\text{Ultimate Load}}{\text{Working Load}}$$
#
# ### **Why Use a Factor of Safety?**
#
# Engineers use FoS to account for:
# 1. **Material variability** - Not all materials are exactly the same
# 2. **Dynamic loads** - Sudden impacts or vibrations
# 3. **Wear and aging** - Structures degrade over time
# 4. **Unknown factors** - Unexpected conditions
# 5. **Human safety** - Extra margin to protect lives
#
# ### **Example: Crane Load Rating**
#
# Remember our crane example?
# - **Theoretical capacity:** 807 lbs
# - **Manufacturer rating:** 220 lbs
#
# Let's calculate the Factor of Safety:
#
# $$\text{FoS} = \frac{807 \text{ lbs}}{220 \text{ lbs}} = 3.67$$
#
# **What does FoS = 3.67 mean?**
#
# The crane can theoretically handle **3.67 times** more than its rated capacity! This large safety factor accounts for:
# - Sudden jerks when lifting
# - Wind loads
# - Material imperfections
# - Long-term reliability
#
# ### **Typical Factors of Safety:**
#
# | Application | Typical FoS | Reason |
# |-------------|-------------|--------|
# | Aircraft | 1.5 - 2.0 | Weight is critical |
# | Buildings | 2.0 - 3.0 | Balance safety & cost |
# | Elevators | 5.0 - 8.0 | Human safety critical |
# | Cranes | 3.0 - 5.0 | Dynamic loads |
# | Bridges | 3.0 - 5.0 | Public safety |

# %%
# Student Task: Calculate Factor of Safety
# ==========================================

# Given data from crane example
theoretical_capacity = 807  # lbs (calculated)
working_load = 220  # lbs (manufacturer rating)

# Calculate Factor of Safety
FoS = theoretical_capacity / working_load

print("="*50)
print("FACTOR OF SAFETY CALCULATION")
print("="*50)
print(f"Theoretical Capacity: {theoretical_capacity} lbs")
print(f"Working Load (Rated): {working_load} lbs")
print(f"\nFactor of Safety: {FoS:.2f}")
print("="*50)

# Interpretation
print(f"\nInterpretation:")
print(f"The crane can handle {FoS:.2f}x its rated capacity.")
print(f"This means it has a {((FoS-1)*100):.0f}% safety margin.")

# Practice: Try different values
print(f"\n💡 Practice:")
print(f"What if the working load was 300 lbs?")
print(f"Calculate the new FoS below:")

# TODO: Calculate FoS for working_load = 300 lbs
# working_load_new = 300
# FoS_new = theoretical_capacity / working_load_new
# print(f"New FoS: {FoS_new:.2f}")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On the other hand, if the net is delicately displaced, and its center of mass shifts slightly away from the geometric center, it may start sliding further in that direction. This represents unstable equilibrium, where a slight disturbance leads to continuous motion. If the net continues to tip past the second picture so that the center of gravity has past the pivot point, $F_N$, we get to the third picture where the net is toppling. This is because the normal force upward on the object can be exerted only within the area of contact. That means that if the weight acts beyond this area, a net torque will topple the fish.

# %% [markdown]
# ## **Key Takeaway** 💡
#
# The key takeaway from this lesson is the recognition of the second condition for equilibrium, focusing on the role of torques in rotational stability. Students will understand that while the sum of forces and moments in the vertical and horizontal directions ensures translational equilibrium, an additional consideration is necessary to address rotational equilibrium.
